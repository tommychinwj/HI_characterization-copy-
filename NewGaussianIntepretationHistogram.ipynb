# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.shape(np.load('/lustre/aoc/projects/hera/wchin/gaussians.npy')[-4, :2])
# Out:
# (2, 100000)

# %%
np.shape(np.load('/lustre/aoc/projects/hera/wchin/gaussians_z6.0_r10.npy'))
# Out:
# (1, 1, 100000)

# %%
gaussians = np.zeros((1, 3, 100000))
gaussians[0, 0] = np.load('/lustre/aoc/projects/hera/wchin/gaussians_z6.0_r10.npy')
gaussians[0, 1:] = np.load('/lustre/aoc/projects/hera/wchin/gaussians.npy')[-4, :2]

# %%
gaussians = np.zeros((1, 3, 100000))
gaussians[0, 0] = np.load('/lustre/aoc/projects/hera/wchin/gaussians_z6.0_r10.npy')
gaussians[0, 1:] = np.load('/lustre/aoc/projects/hera/wchin/gaussians.npy')[-4, :2]

color = 'w'
radius = np.arange(10, 7, -1)

fig = plt.figure(dpi=500, facecolor='#404040')
ax = fig.gca()
for spine in ax.spines.values():  # figure color
    spine.set_edgecolor(color)
bin_edges = np.linspace(0., 1., 50) # bin_num of bins from 0-1
bin_centers = 0.5 * (bin_edges[1:] + bin_edges[:-1])

for i in range(3):
    plt.semilogy(
        bin_centers,
        np.histogram(gaussians[0, i], bins=bin_edges)[0],
        label=f'r = {radius[i]}'
    )
plt.legend(framealpha=0.)
plt.title(f'$z = 6.0,$' r'$ \langle x_{HI} \rangle $' f'$ = {0.08*100.:.2f} \%$', color=color)
plt.xlabel(f'Neutral Fraction, $x_{{HI}}$', color=color)
plt.ylabel('Sphere Counts', color=color)
plt.tick_params(color=color, labelcolor=color, which='both')
plt.show()

# %%
gaussians = np.load('/lustre/aoc/projects/hera/wchin/gaussians_z6.5_r12,11,10.npy')
color = 'w'
radius = np.arange(12, 9, -1)

fig = plt.figure(dpi=500, facecolor='#404040')
ax = fig.gca()
for spine in ax.spines.values():  # figure color
    spine.set_edgecolor(color)
bin_edges = np.linspace(0., 1., 50) # bin_num of bins from 0-1
bin_centers = 0.5 * (bin_edges[1:] + bin_edges[:-1])

for i in range(3):
    plt.semilogy(
        bin_centers,
        np.histogram(gaussians[0, i], bins=bin_edges)[0],
        label=f'r = {radius[i]}'
    )
plt.legend(framealpha=0.)
plt.title(f'$z = 6.5,$' r'$ \langle x_{HI} \rangle $' f'$ = {0.1891804*100.:.2f} \%$', color=color)
plt.xlabel(f'Neutral Fraction, $x_{{HI}}$', color=color)
plt.ylabel('Sphere Counts', color=color)
plt.tick_params(color=color, labelcolor=color, which='both')
plt.show()

# %%
gaussians = np.load('/lustre/aoc/projects/hera/wchin/gaussians_z7.5_r14,13,12.npy')
gaussians_z7p5_r16_15 = np.load('/lustre/aoc/projects/hera/wchin/gaussians_z7.5_r16,15.npy')

color = 'w'
radius = np.arange(14, 11, -1)

fig = plt.figure(dpi=500, facecolor='#404040')
ax = fig.gca()
for spine in ax.spines.values():  # figure color
    spine.set_edgecolor(color)
bin_edges = np.linspace(0., 1., 50) # bin_num of bins from 0-1
bin_centers = 0.5 * (bin_edges[1:] + bin_edges[:-1])

for i in range(1, 2):
    plt.semilogy(
        bin_centers,
        np.histogram(gaussians_z7p5_r16_15[0, i], bins=bin_edges)[0],
        label=f'r = {np.array([16, 15])[i]}'
    )

for i in range(2):
    plt.semilogy(
        bin_centers,
        np.histogram(gaussians[0, i], bins=bin_edges)[0],
        label=f'r = {radius[i]}'
    )
plt.legend(framealpha=0.)
plt.title(f'$z = 7.5,$' r'$ \langle x_{HI} \rangle $' f'$ = {4.94936030e-01*100.:.2f} \%$', color=color)
plt.xlabel(f'Neutral Fraction, $x_{{HI}}$', color=color)
plt.ylabel('Sphere Counts', color=color)
plt.tick_params(color=color, labelcolor=color, which='both')
plt.show()

# %%
gaussians = np.load('/lustre/aoc/projects/hera/wchin/gaussians_z8.5_r22,21,20.npy')
color = 'w'
radius = np.arange(22, 19, -1)

fig = plt.figure(dpi=500)
ax = fig.gca()
for spine in ax.spines.values():  # figure color
    spine.set_edgecolor(color)
bin_edges = np.linspace(0., 1., 50) # bin_num of bins from 0-1
bin_centers = 0.5 * (bin_edges[1:] + bin_edges[:-1])

for i in range(3):
    plt.semilogy(
        bin_centers,
        np.histogram(gaussians[0, i], bins=bin_edges)[0],
        label=f'r = {radius[i]}'
    )
plt.legend(framealpha=0.)
plt.title(f'$z = 8.5,$' r'$ \langle x_{HI} \rangle $' f'$ = {0.7325*100.:.2f} \%$', color=color)
plt.xlabel(f'Neutral Fraction, $x_{{HI}}$', color=color)
plt.ylabel('Sphere Counts', color=color)
plt.tick_params(color=color, labelcolor=color, which='both')
plt.show()

# %% [markdown]
# newGaussians_z8p5_7p5_6p5_6 = np.zeros((4, 3, 100000))
# newGaussians_z8p5_7p5_6p5_6[0] = np.load('/lustre/aoc/projects/hera/wchin/gaussians_z8.5_r22,21,20.npy')
# newGaussians_z8p5_7p5_6p5_6[1, 0] = np.load('/lustre/aoc/projects/hera/wchin/gaussians_z7.5_r16,15.npy')[0, 1]
# newGaussians_z8p5_7p5_6p5_6[1, 1:] = np.load('/lustre/aoc/projects/hera/wchin/gaussians_z7.5_r14,13,12.npy')[0, :2]
# newGaussians_z8p5_7p5_6p5_6[2] = np.load('/lustre/aoc/projects/hera/wchin/gaussians_z6.5_r12,11,10.npy')
# newGaussians_z8p5_7p5_6p5_6[3, 0] = np.load('/lustre/aoc/projects/hera/wchin/gaussians_z6.0_r10.npy')
# newGaussians_z8p5_7p5_6p5_6[3, 1:] = np.load('/lustre/aoc/projects/hera/wchin/gaussians.npy')[-4, :2]

# %% [markdown]
# np.save('/lustre/aoc/projects/hera/wchin/newGaussians_z8p5_7p5_6p5_6', newGaussians_z8p5_7p5_6p5_6)

# %%
newGaussians_z8p5_7p5_6p5_6 = np.load('/lustre/aoc/projects/hera/wchin/newGaussians_z8p5_7p5_6p5_6.npy')

# %% [markdown]
# ## Check if object is iterable

# %%
def iterable(obj):
    
    try:
        iter(obj)
        
    except Exception:
        return False
    
    else:
        return True

# %% [markdown]
# ## Histogram Function

# %%
def histogram(
    y1s, 
    figure_shape, 
    y2s=None,
    y3s=None,
    marker_lines=None,
    y1s_labels=None,
    y2s_label=None,
    y3s_label=None,
    title=None, 
    legend_font_size=12,
    fancy_legend_box=True,
    legend_alpha=0.5,
    shared_title=None,
    shared_title_x_position=0.5,   # figure coordinates, max=1 I think
    shared_title_y_position=0.92,
    shared_x_label=None, 
    shared_x_label_x_position=0.5,
    shared_x_label_y_position=0.08,
    shared_y_label=None, 
    shared_y_label_x_position=0.07,
    shared_y_label_y_postion=0.5,
    x_start=0, 
    x_stop=1, 
    bin_num=int(1e3), 
    color='white', 
    figure_size=(18,7), 
    font_size=15, 
    horizontal_gap=0.05, 
    vertical_gap=0.05, 
    y_scale='linear', 
    y_notation='plain', 
    share_x_axis=True, 
    share_y_axis=True,
    dpi=100
):  # a: x start, b: x stop
    
    bin_edges = np.linspace(x_start, x_stop, bin_num) # bin_num of bins from 0-1
    
    bin_centers = 0.5 * (bin_edges[1:] + bin_edges[:-1])
    
    if np.array(y1s).ndim > 2:  # hopefully more robust condition.
        
        fig, axes = plt.subplots(
            figure_shape[0], 
            figure_shape[1], 
            figsize=figure_size, 
            sharex=share_x_axis, 
            sharey=share_y_axis, 
            gridspec_kw={"hspace":vertical_gap, 'wspace':horizontal_gap},
            dpi=dpi,
            facecolor='#404040'
        )
        
        if shared_title != None:
            
            fig.suptitle(
                x=shared_title_x_position, 
                y=shared_title_y_position, 
                t=shared_title, ha='center', 
                size=1.5*font_size, 
                color=color
            )
            
        if shared_x_label != None:  # shared x label
            fig.text(
                x=shared_x_label_x_position, 
                y=shared_x_label_y_position, 
                s=shared_x_label, ha='center', 
                size=font_size, 
                color=color
            )

        if shared_y_label != None:  # shared y label
            fig.text(
                x=shared_y_label_x_position, 
                y=shared_y_label_y_postion, 
                s=shared_y_label, 
                va='center', 
                rotation='vertical', 
                size=font_size, 
                color=color
            )
        
        for i, y1 in enumerate(y1s):
            
            for ii, marker_line in enumerate(marker_lines):
                
                axes.flatten()[i].plot(
                    bin_centers, 
                    np.histogram(y1s[i,ii,:], bins=bin_edges)[0], 
                    marker_line,
                    label=np.array(y1s_labels)[i, ii],
                    alpha=0.75
            )
            
            if iterable(y2s):
                axes.flatten()[i].plot(
                    bin_centers, 
                    np.histogram(y2s[i], bins=bin_edges)[0], 
                    '--', 
                    label=y2s_label
                )
                
                if iterable(y3s):
                    axes.flatten()[i].plot(
                        bin_centers, 
                        np.histogram(y3s[i], bins=bin_edges)[0], 
                        label=y3s_label
                    )
                    
                    
            if y1s_labels != None:
                axes.flatten()[i].legend(
                    prop={'size': legend_font_size}, 
                    fancybox=fancy_legend_box, 
                    framealpha=legend_alpha
                )
                
            if title != None:
                axes.flatten()[i].set_title(title[i], color=color, fontsize=font_size)
                
            axes.flatten()[i].set_yscale(y_scale)
            
            if y_notation == 'sci':
                axes.flatten()[i].ticklabel_format(
                    axis='y', 
                    style=y_notation, 
                    scilimits=(0,0), 
                    useMathText=True
                )
                
            axes.flatten()[i].tick_params(
                color=color, 
                labelcolor=color, 
                labelsize=font_size, 
                which='both'
            )  # font style

            for spine in axes.flatten()[i].spines.values():  # figure color
                spine.set_edgecolor(color)
                
    else:
        
        fig, ax = plt.subplots(figsize=figure_size)
        
        ax.plot(bin_centers, np.histogram(y1s, bins=bin_edges)[0], label=y1s_labels)
        
        if y2s != None:
            ax.plot(bin_centers, np.histogram(y2s, bins=bin_edges)[0], '--', label=y2s_label)
            
            if y3s == None:
                ax.legend(
                    prop={'size': legend_font_size}, 
                    fancybox=fancy_legend_box, 
                    framealpha=legend_alpha
                )                 
                
            else:
                ax.plot(bin_centers, np.histogram(y3s, bins=bin_edges)[0], '-.', label=y3s_label)
                ax.legend(
                    prop={'size': legend_font_size}, 
                    fancybox=fancy_legend_box, 
                    framealpha=legend_alpha
                )                 
                
        if title != None:
            ax.set_title(title, color=color, fontsize=font_size)
            
        ax.set_yscale(y_scale)
        
        if y_notation == 'sci':
            ax.ticklabel_format(axis='y', style=y_notation, scilimits=(0,0), useMathText=True)
            
        ax.tick_params(color=color, labelcolor=color, labelsize=font_size, which='both')  # font style

        for spine in ax.spines.values():  # figure color
            spine.set_edgecolor(color)
            
    plt.show()

# %%
redshifts = np.array([8.5, 7.5, 6.5, 6.0])
total_neutral_fractions = np.array([0.73249981, 0.49493603, 0.1891804 , 0.07996972])
sphere_radii = np.array([np.array([22, 21, 20]), np.array([15, 14, 13]), np.array([12, 11, 10]), np.array([10, 9, 8])])
bins = int(2e2)
labels = [[f'radius={radius:d}Mpc' for radius in sphere_radii[0]], [f'radius={radius:d}Mpc' for radius in sphere_radii[1]], [f'radius={radius:d}Mpc' for radius in sphere_radii[2]], [f'radius={radius:d}Mpc' for radius in sphere_radii[3]]]
histogram(
    y1s=newGaussians_z8p5_7p5_6p5_6,       
    marker_lines=['-']*np.shape(sphere_radii)[1],
    y1s_labels=labels,
    legend_alpha=0,
    bin_num=bins,   
    title=[f'$z = {redshifts[i]},$' r'$ \langle x_{HI} \rangle $' f'$ = {total_neutral_fractions[i]:.2f}$' for i in range(len(redshifts))],
    shared_title=f'Gaussian Sphere Method',
    shared_title_y_position=0.95,
    shared_y_label='Sphere Counts',
    shared_x_label=f'Neutral Fraction, $x_{{HI}}$',
    shared_x_label_y_position=0.070,
    shared_y_label_x_position=0.055,
    figure_shape=(2,2), 
    figure_size=(11,10),
    vertical_gap=0.1,
    horizontal_gap=0.05,
    y_scale='log',
#     y_notation='sci',
    share_y_axis=True,
    dpi=500,
    color='w'
)

# %%
gaussians = np.load('/lustre/aoc/projects/hera/wchin/gaussians_z7.5_r14,13,12.npy')
gaussians_z7p5_r16_15 = np.load('/lustre/aoc/projects/hera/wchin/gaussians_z7.5_r16,15.npy')

color = 'w'
radius = np.arange(14, 11, -1)

fig = plt.figure(dpi=500, facecolor='#404040')
ax = fig.gca()
for spine in ax.spines.values():  # figure color
    spine.set_edgecolor(color)
bin_edges = np.linspace(0., 1., 50) # bin_num of bins from 0-1
bin_centers = 0.5 * (bin_edges[1:] + bin_edges[:-1])

for i in range(2):
    plt.semilogy(
        bin_centers,
        np.histogram(gaussians_z7p5_r16_15[0, i], bins=bin_edges)[0],
        label=f'r = {np.array([16, 15])[i]}'
    )

for i in range(3):
    plt.semilogy(
        bin_centers,
        np.histogram(gaussians[0, i], bins=bin_edges)[0],
        label=f'r = {radius[i]}'
    )
plt.legend(framealpha=0.)
plt.title(f'$z = 7.5,$' r'$ \langle x_{HI} \rangle $' f'$ = {4.94936030e-01*100.:.2f} \%$', color=color)
plt.xlabel(f'Neutral Fraction, $x_{{HI}}$', color=color)
plt.ylabel('Sphere Counts', color=color)
plt.tick_params(color=color, labelcolor=color, which='both')
plt.show()
